# %% [markdown]
# # **NAME : AKHIL SHARON S**
# # TASK : SALES PREDICTION

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/Advertising.csv")

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.shape
# Out:
# (200, 5)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df=df.drop(columns=["Unnamed: 0"])

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
x=df.iloc[:, 0:-1]

# %%
x
# Out:
#         TV  Radio  Newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4,random_state=40)

# %%
x_train
# Out:
#         TV  Radio  Newspaper
# 9    199.8    2.6       21.2
# 2     17.2   45.9       69.3
# 97   184.9   21.0       22.0
# 66    31.5   24.6        2.2
# 6     57.5   32.8       23.5
# ..     ...    ...        ...
# 50   199.8    3.1       34.6
# 184  253.8   21.3       30.0
# 165  234.5    3.4       84.8
# 7    120.2   19.6       11.6
# 70   199.1   30.6       38.7
#
# [120 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Radio  Newspaper
# 96   197.6    3.5        5.9
# 5      8.7   48.9       75.0
# 116  139.2   14.3       25.6
# 35   290.7    4.1        8.5
# 183  287.6   43.0       71.8
# ..     ...    ...        ...
# 17   281.4   39.6       55.8
# 56     7.3   28.1       41.4
# 103  187.9   17.2       17.9
# 39   228.0   37.7       32.0
# 137  273.7   28.9       59.7
#
# [80 rows x 3 columns]

# %%
y_train
# Out:
# 9      10.6
# 2       9.3
# 97     15.5
# 66      9.5
# 6      11.8
#        ...
# 50     11.4
# 184    17.6
# 165    11.9
# 7      13.2
# 70     18.3
# Name: Sales, Length: 120, dtype: float64

# %%
y_test
# Out:
# 96     11.7
# 5       7.2
# 116    12.2
# 35     12.8
# 183    26.2
#        ...
# 17     24.4
# 56      5.5
# 103    14.7
# 39     21.5
# 137    20.8
# Name: Sales, Length: 80, dtype: float64

# %%
x_train=x_train.astype(int)
y_train=y_train.astype(int)
x_test=x_test.astype(int)
y_test=y_test.astype(int)

# %%
from sklearn.preprocessing import StandardScaler
Sc=StandardScaler()
x_train_scaled=Sc.fit_transform(x_train)
x_test_scaled=Sc.fit_transform(x_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train_scaled,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test_scaled)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8318154282005961

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test,y_pred,c='g')

# %% [markdown]
# In conclusion, The Sales Prediction task highlights the practical application of machine learning in business analytics. By leveraging historical data and relevant features, these models empower organizations to forecast sales, optimize resource allocation, and refine marketing strategies for enhanced efficiency.
